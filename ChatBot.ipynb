# %%
# !pip install gpt4all
# Out:
# Collecting gpt4all
#   Downloading gpt4all-2.8.2-py3-none-manylinux1_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gpt4all) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gpt4all) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2025.10.5)
# Downloading gpt4all-2.8.2-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: gpt4all
# Successfully installed gpt4all-2.8.2

# %%
# !pip install --upgrade gpt4all
# Out:
# Requirement already satisfied: gpt4all in /usr/local/lib/python3.12/dist-packages (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gpt4all) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gpt4all) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gpt4all) (2025.10.5)

# %%
from gpt4all import GPT4All

model = GPT4All("mistral-7b-instruct-v0.1.Q4_0.gguf")  # include .bin
# Out:
# Downloading: 100%|██████████| 4.11G/4.11G [01:21<00:00, 50.6MiB/s]
# Verifying: 100%|██████████| 4.11G/4.11G [00:09<00:00, 447MiB/s]

# %%
response = model.generate("Explain Python loops in simple words for a beginner.")
print("Example 1 - Explanation of Python loops:")
print(response)
# Out:
# Example 1 - Explanation of Python loops:
#
#
# Python is a popular programming language that allows you to write programs and automate tasks. One of the most common features of any programming language is the ability to repeat certain blocks of code over and over again, which can be achieved using loops. In this article, we will explain Python loops in simple words for beginners.
#
# There are three types of loops in Python: while loops, for loops, and do-while loops. Each type works differently, but they all allow you to repeat a block of code multiple times.
#
# While Loops:
# A while loop is used when you want to repeatedly execute a block of code as long as a certain condition remains true. The basic syntax of a while loop in Python is:
# ```python
# while condition:
#     # code to be executed if the condition is true
# ```
# For example, consider a program that asks a user for their age and then checks whether they are old enough to vote or not

# %%
# simple chatbot loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "stop"]:
        print("Chatbot: Goodbye")
        break

    reply = model.generate(user_input)
    print("Chatbot:", reply)
# Out:
# You: what is gpu vs cpu.
# Chatbot:
#
# what are the advantages and disadvantages of using a gpu?
#
# advantages:
#
# * faster processing speed for certain tasks, such as gaming or video editing
# * more efficient use of memory compared to CPUs
# * can handle multiple tasks simultaneously without slowing down other processes on the computer
# * often have dedicated graphics cards that are optimized for rendering images and videos
#
# disadvantages:
#
# * generally more expensive than CPUs
# * require a separate power supply, which can be bulky and add to the overall size of the system
# * may not be suitable for all types of tasks or applications
# * often have limited processing capabilities compared to CPUs for general-purpose computing tasks.
# You: speak in arabic
# Chatbot:
# =================
#
# .. image:: https://img.shields.io/github/license/arabic-speech-recognition/speakin_arabic.svg?style=flat&maxwidth=100%
#    :target: https://opensource.org/licenses/MIT
#
# .. image:: https://img.shields.io/github/release/arabic-speech-recognition/speakin_arabic.svg?style=flat&maxwidth=100%
#    :target: https://github.com/arabic-speech-recognition/speakin_arabic/releases
#
# .. image:: https://img.shields.io/github/followers/arabic-speech-recognition.svg?style=flat&maxwidth=100%
#    :target: https://
# You: how are u i n arabic
# Chatbot:
#
# i am a computer programmer, and i have been working on developing an application that will help people find information. my application is designed to be used by anyone with access to the internet, regardless of their level of technical expertise. it allows users to search for information using keywords or phrases, and then displays relevant results in a user-friendly format.
#
# i am currently working on improving the accuracy of my application's search algorithm, as well as adding new features that will make it even more useful for users. i am also considering integrating my application with other tools and services, such as social media platforms or online databases, to provide a more comprehensive experience for users.
#
# i am excited about the potential of my application and believe that it has the ability to revolutionize the way people find information on the internet.
# You: exit
# Chatbot: Goodbye

# %%
text = """
Python is a high-level, interpreted programming language.
It is widely used for web development, data analysis, artificial intelligence, and more.
"""

summary = model.generate(f"Summarize this text in one sentence: {text}")
print("\nExample 2 - Summary of text:")
print(summary)
# Out:
# Example 2 - Summary of text:
# Its simplicity and versatility make it an excellent choice for beginners and experts alike.

# %%
text = "Machine learning allows computers to find patterns in data and make decisions without being explicitly programmed."

summary = model.generate(f"Give a short summary of this text: {text}")

translation = model.generate(f"Translate this summary into French: {summary}")

print("Example 4")
print("Summary:", summary)
print("Translation:", translation)
# Out:
# Example 4
# Summary:  It is based on statistical models, which are derived from sample data, and can be used for tasks such as classification, prediction, decision-making, and control. Machine learning algorithms use techniques like supervised learning, unsupervised learning, reinforcement learning, and deep learning to learn patterns in data and make predictions or decisions. These algorithms can be trained on large datasets and can improve their performance over time as they gain experience with new data.
# Translation:

# %%
text = "Machine learning allows computers to find patterns in data and make decisions without being explicitly programmed."


translation = model.generate(f"Translate this summary into Urdu: {summary}")

print("Example 4")
print("Translation:", translation)
# Out:
# Example 4
# Translation:
